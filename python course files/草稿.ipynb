# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.datasets import fetch_20newsgroups
from sklearn.decomposition import NMF, LatentDirichletAllocation

def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print( "Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

dataset = fetch_20newsgroups(shuffle=True, random_state=1, remove=('headers', 'footers', 'quotes'))
documents = dataset.data

no_features = 1000

# NMF is able to use tf-idf
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(documents)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
vocab=tfidf_vectorizer.vocabulary_

# %%
type(vocab)
# Out:
# dict

# %%
vocab
# Out:
# {'sure': 872,
#  'story': 860,
#  'did': 303,
#  'statement': 854,
#  'media': 589,
#  'pro': 714,
#  'israeli': 497,
#  'world': 985,
#  'having': 444,
#  'letter': 535,
#  'try': 914,
#  'think': 897,
#  'reason': 745,
#  'report': 760,
#  'clearly': 229,
#  'reports': 762,
#  'received': 748,
#  'government': 424,
#  'makes': 573,
#  'away': 146,
#  'look': 554,
#  'jews': 502,
#  'got': 422,
#  'power': 703,
#  'expect': 359,
#  'people': 670,
#  'read': 741,
#  'faq': 369,
#  'actually': 88,
#  'accept': 83,
#  'hard': 441,
#  'atheism': 138,
#  'need': 620,
#  'little': 546,
#  'faith': 366,
#  'runs': 781,
#  'jim': 503,
#  'sorry': 837,
#  'oh': 644,
#  'just': 508,
#  'end': 341,
#  'maybe': 584,
#  'start': 851,
#  'new': 625,
#  'newsgroup': 627,
#  'alt': 103,
#  'won': 978,
#  'big': 162,
#  'don': 321,
#  'points': 691,
#  'like': 540,
#  'know': 516,
#  'ask': 134,
#  'question': 734,
#  'sort': 838,
#  'want': 954,
#  'continue': 258,
#  'israel': 496,
#  'stop': 859,
#  'asking': 136,
#  'questions': 735,
#  'work': 981,
#  'bad': 149,
#  'attack': 139,
#  'group': 429,
#  'center': 203,
#  'policy': 693,
#  'research': 767,
#  'change': 207,
#  'product': 719,
#  'area': 124,
#  'clipper': 231,
#  'came': 191,
#  'key': 509,
#  'yes': 997,
#  'technology': 886,
#  'drive': 325,
#  'cost': 263,
#  'use': 931,
#  'present': 705,
#  'man': 575,
#  'street': 861,
#  'going': 420,
#  'especially': 349,
#  'guy': 434,
#  'probably': 715,
#  'doesn': 319,
#  'real': 743,
#  'gov': 423,
#  'year': 995,
#  'air': 98,
#  'voice': 949,
#  'privacy': 712,
#  'phone': 676,
#  'line': 543,
#  'close': 232,
#  'pc': 668,
#  'unfortunately': 924,
#  'time': 900,
#  'right': 773,
#  'certainly': 205,
#  'post': 700,
#  'rules': 778,
#  'does': 318,
#  'matter': 582,
#  'll': 550,
#  'good': 421,
#  'let': 534,
#  'mail': 569,
#  'edu': 336,
#  'league': 529,
#  'old': 646,
#  'wasn': 959,
#  'dead': 288,
#  'jesus': 500,
#  'appears': 113,
#  'day': 284,
#  'normal': 632,
#  'ok': 645,
#  'record': 751,
#  'small': 831,
#  'programs': 722,
#  '64': 65,
#  'lot': 560,
#  '40': 56,
#  'average': 144,
#  '20': 28,
#  '25': 34,
#  'difference': 306,
#  'great': 426,
#  'simple': 822,
#  'card': 194,
#  'better': 158,
#  'says': 792,
#  'cards': 195,
#  'offer': 641,
#  'bought': 173,
#  'problems': 717,
#  'complete': 247,
#  'check': 210,
#  'called': 189,
#  'performance': 672,
#  'numbers': 637,
#  'file': 380,
#  'mr': 612,
#  '33': 46,
#  'sounds': 840,
#  'mean': 586,
#  'peace': 669,
#  'process': 718,
#  'say': 790,
#  'test': 890,
#  '18': 19,
#  'months': 608,
#  'known': 518,
#  'terms': 889,
#  'saying': 791,
#  'reasons': 747,
#  'make': 572,
#  'california': 188,
#  'allowed': 102,
#  'force': 391,
#  'food': 390,
#  'leave': 531,
#  'include': 475,
#  'way': 961,
#  'wouldn': 987,
#  'light': 539,
#  'electronic': 338,
#  'remember': 758,
#  'total': 907,
#  'kind': 514,
#  'memory': 592,
#  'non': 631,
#  'outside': 658,
#  '10': 8,
#  'years': 996,
#  'life': 538,
#  'doing': 320,
#  'legal': 533,
#  'used': 932,
#  'car': 193,
#  '100': 9,
#  '200': 29,
#  'looks': 557,
#  'easy': 334,
#  'price': 710,
#  'tell': 887,
#  'thanks': 893,
#  'archive': 123,
#  'graphics': 425,
#  'list': 545,
#  '1993': 24,
#  '04': 5,
#  '17': 18,
#  'computer': 249,
#  'posting': 702,
#  'april': 122,
#  'including': 478,
#  'available': 143,
#  'site': 826,
#  'manager': 576,
#  'mit': 601,
#  '27': 37,
#  'directory': 311,
#  'pub': 729,
#  'usenet': 934,
#  'news': 626,
#  'answers': 109,
#  'article': 132,
#  'server': 813,
#  'machine': 567,
#  'send': 808,
#  'message': 596,
#  'help': 451,
#  'body': 170,
#  'places': 684,
#  'information': 481,
#  'changed': 208,
#  'order': 652,
#  'plan': 685,
#  'soon': 836,
#  'keys': 511,
#  'subject': 865,
#  '3d': 54,
#  'public': 730,
#  'free': 394,
#  'systems': 874,
#  'stuff': 864,
#  'thinking': 898,
#  'making': 574,
#  'lines': 544,
#  'changes': 209,
#  'text': 891,
#  '1992': 23,
#  'copy': 261,
#  'provided': 726,
#  'contact': 255,
#  'software': 833,
#  'suggest': 866,
#  'reading': 742,
#  'comp': 245,
#  'image': 471,
#  'analysis': 106,
#  'date': 281,
#  'asked': 135,
#  'john': 506,
#  'nasa': 615,
#  'official': 643,
#  'included': 476,
#  'comments': 240,
#  'ftp': 397,
#  'related': 754,
#  'commercial': 241,
#  'display': 314,
#  '11': 10,
#  'data': 280,
#  'files': 381,
#  '12': 11,
#  '13': 13,
#  '14': 14,
#  '15': 16,
#  'space': 845,
#  'shuttle': 820,
#  '16': 17,
#  'scientific': 796,
#  '19': 20,
#  'future': 400,
#  'info': 480,
#  'groups': 430,
#  'usually': 939,
#  'articles': 133,
#  'posted': 701,
#  'times': 901,
#  'month': 607,
#  'field': 378,
#  'port': 696,
#  'type': 921,
#  'place': 683,
#  'com': 235,
#  'general': 406,
#  'switch': 873,
#  'network': 624,
#  'word': 979,
#  'following': 389,
#  'user': 935,
#  'anonymous': 107,
#  'internet': 493,
#  'address': 91,
#  'cd': 202,
#  'required': 765,
#  'service': 814,
#  'appreciated': 118,
#  'au': 140,
#  '128': 12,
#  'cs': 274,
#  'ac': 82,
#  '24': 33,
#  'uk': 922,
#  'net': 623,
#  'usa': 930,
#  'x11': 993,
#  'tape': 880,
#  'sources': 842,
#  'sites': 827,
#  'note': 634,
#  'users': 936,
#  'united': 926,
#  'number': 636,
#  'things': 896,
#  'response': 768,
#  'email': 339,
#  'unix': 928,
#  'hours': 462,
#  'days': 285,
#  'later': 525,
#  '26': 36,
#  '03': 4,
#  '93': 78,
#  'mac': 566,
#  'son': 835,
#  'written': 990,
#  'dave': 282,
#  'ca': 186,
#  'range': 739,
#  'package': 659,
#  'ii': 470,
#  'ms': 613,
#  'dos': 322,
#  'version': 945,
#  'exists': 358,
#  'author': 141,
#  'source': 841,
#  '50': 61,
#  'steve': 858,
#  'interesting': 489,
#  'hp': 464,
#  'series': 812,
#  'needs': 622,
#  'sun': 867,
#  'volume': 950,
#  'excellent': 355,
#  'based': 151,
#  'machines': 568,
#  'includes': 477,
#  'house': 463,
#  'solution': 834,
#  'run': 779,
#  'box': 174,
#  'requires': 766,
#  'uses': 937,
#  'algorithm': 100,
#  'command': 239,
#  'interface': 490,
#  'program': 721,
#  'set': 815,
#  'write': 988,
#  'code': 233,
#  'format': 393,
#  'widget': 969,
#  'applications': 116,
#  'environment': 346,
#  'device': 301,
#  'library': 537,
#  'fast': 371,
#  'dr': 324,
#  'output': 657,
#  'support': 869,
#  'major': 571,
#  '250': 35,
#  'save': 788,
#  'extra': 363,
#  'al': 99,
#  'looking': 556,
#  'imagine': 473,
#  'nice': 629,
#  'object': 638,
#  'material': 581,
#  'cross': 273,
#  'paper': 661,
#  'project': 723,
#  'various': 943,
#  'technical': 885,
#  'form': 392,
#  '000': 1,
#  'community': 244,
#  'org': 653,
#  'access': 84,
#  'wish': 975,
#  'tools': 906,
#  'writing': 989,
#  'images': 472,
#  'screen': 797,
#  'windows': 973,
#  'bit': 164,
#  'gif': 410,
#  'color': 234,
#  'san': 786,
#  'useful': 933,
#  'books': 172,
#  'tar': 881,
#  '75': 68,
#  'means': 588,
#  'north': 633,
#  'america': 104,
#  '21': 30,
#  'lots': 561,
#  'book': 171,
#  'trouble': 911,
#  'specific': 847,
#  '36': 50,
#  '23': 32,
#  'david': 283,
#  '31': 44,
#  'multiple': 614,
#  'created': 271,
#  '80': 72,
#  '32': 45,
#  'mark': 578,
#  '35': 49,
#  '90': 75,
#  'window': 972,
#  '38': 52,
#  'manual': 577,
#  'contains': 256,
#  '42': 57,
#  'apparently': 112,
#  'longer': 553,
#  'language': 522,
#  'standard': 850,
#  'best': 157,
#  'issues': 499,
#  'jpeg': 507,
#  'export': 362,
#  '30': 42,
#  'paul': 666,
#  'recently': 750,
#  '22': 31,
#  'apple': 114,
#  '43': 58,
#  'conference': 251,
#  'video': 947,
#  '91': 76,
#  '92': 77,
#  'international': 492,
#  'near': 618,
#  'washington': 958,
#  'built': 181,
#  'science': 795,
#  'final': 382,
#  'exist': 356,
#  'state': 853,
#  'course': 267,
#  '86': 74,
#  'considered': 254,
#  'short': 818,
#  'digital': 309,
#  'human': 465,
#  'head': 445,
#  'provides': 727,
#  'distribution': 315,
#  'different': 307,
#  'rom': 776,
#  'modem': 604,
#  'bits': 165,
#  'main': 570,
#  'function': 398,
#  '300': 43,
#  'land': 521,
#  'particular': 662,
#  'details': 299,
#  'sci': 794,
#  'entire': 344,
#  'carry': 197,
#  'add': 89,
#  'vga': 946,
#  'come': 236,
#  'using': 938,
#  'medical': 590,
#  'ago': 95,
#  '60': 64,
#  'east': 333,
#  '70': 67,
#  'plus': 689,
#  'room': 777,
#  'wrong': 991,
#  'return': 772,
#  'follow': 388,
#  'reply': 759,
#  'answer': 108,
#  'original': 655,
#  'sent': 810,
#  'request': 763,
#  'ibm': 466,
#  'week': 964,
#  'example': 354,
#  'point': 690,
#  'base': 150,
#  'entry': 345,
#  'chicago': 211,
#  'canada': 192,
#  'os': 656,
#  'currently': 276,
#  'long': 552,
#  'york': 998,
#  'running': 780,
#  'sound': 839,
#  'special': 846,
#  'given': 411,
#  'st': 849,
#  'supports': 870,
#  'design': 297,
#  'interested': 488,
#  'addition': 90,
#  'basic': 152,
#  'rate': 740,
#  'directly': 310,
#  'fax': 374,
#  'satellite': 787,
#  'office': 642,
#  'road': 775,
#  'van': 942,
#  'create': 270,
#  '28': 38,
#  '1991': 22,
#  'money': 605,
#  'release': 755,
#  'easily': 332,
#  'feel': 377,
#  'possible': 698,
#  '45': 60,
#  '00': 0,
#  'disk': 313,
#  'army': 131,
#  'block': 167,
#  'half': 435,
#  'picture': 679,
#  'university': 927,
#  '800': 73,
#  'president': 706,
#  'south': 843,
#  'city': 224,
#  'department': 295,
#  'worth': 986,
#  '29': 39,
#  'personal': 675,
#  'station': 856,
#  'model': 603,
#  'devices': 302,
#  'party': 664,
#  'cover': 269,
#  'administration': 92,
#  'shipping': 817,
#  '500': 62,
#  'basically': 153,
#  'build': 179,
#  'application': 115,
#  'theory': 894,
#  'low': 563,
#  'internal': 491,
#  'heard': 448,
#  'company': 246,
#  'person': 674,
#  'today': 903,
#  'period': 673,
#  'building': 180,
#  'young': 999,
#  'higher': 454,
#  'fine': 384,
#  'ma': 565,
#  'pittsburgh': 681,
#  'mouse': 611,
#  'motif': 610,
#  'open': 648,
#  'transfer': 909,
#  'define': 293,
#  'current': 275,
#  'working': 983,
#  'mike': 597,
#  '44': 59,
#  'sale': 785,
#  'condition': 250,
#  'really': 744,
#  '55': 63,
#  'recent': 749,
#  'pay': 667,
#  'term': 888,
#  'hi': 452,
#  'according': 85,
#  'nature': 617,
#  'left': 532,
#  'control': 259,
#  'god': 418,
#  'obviously': 640,
#  'live': 547,
#  'choice': 216,
#  'title': 902,
#  'political': 694,
#  'appropriate': 120,
#  'exactly': 353,
#  'chip': 214,
#  'secret': 801,
#  'child': 212,
#  'citizens': 223,
#  'arms': 130,
#  'purpose': 732,
#  'private': 713,
#  'quality': 733,
#  'season': 799,
#  'pick': 678,
#  'thought': 899,
#  'case': 199,
#  'generally': 407,
#  'belief': 155,
#  'important': 474,
#  'issue': 498,
#  'said': 784,
#  'organization': 654,
#  'bible': 161,
#  'anti': 110,
#  'believe': 156,
#  'fact': 365,
#  'christ': 217,
#  'children': 213,
#  'sense': 809,
#  'works': 984,
#  'red': 752,
#  'agree': 96,
#  'simply': 823,
#  'needed': 621,
#  'trying': 915,
#  'words': 980,
#  'large': 523,
#  'common': 242,
#  'seen': 805,
#  'deal': 289,
#  'tv': 920,
#  'parts': 663,
#  'shot': 819,
#  'player': 687,
#  'worked': 982,
#  'lower': 564,
#  'inside': 483,
#  'thing': 895,
#  'likely': 541,
#  'hand': 436,
#  'far': 370,
#  'class': 227,
#  'idea': 468,
#  'rights': 774,
#  'quite': 736,
#  'lord': 558,
#  'freedom': 395,
#  'religion': 756,
#  'team': 883,
#  'nhl': 628,
#  'early': 330,
#  'gm': 416,
#  'national': 616,
#  'play': 686,
#  'second': 800,
#  'guess': 431,
#  'country': 265,
#  'mention': 594,
#  'father': 373,
#  'love': 562,
#  'understand': 923,
#  'context': 257,
#  'christians': 220,
#  'hell': 450,
#  'basis': 154,
#  'secure': 803,
#  'care': 196,
#  'wants': 956,
#  'christianity': 219,
#  'home': 459,
#  'bring': 176,
#  'willing': 970,
#  'chips': 215,
#  'similar': 821,
#  'effect': 337,
#  'des': 296,
#  'encryption': 340,
#  'knows': 519,
#  'possibly': 699,
#  'discussion': 312,
#  'knowledge': 517,
#  'game': 402,
#  'vs': 951,
#  'ways': 962,
#  'comes': 237,
#  'crime': 272,
#  'communications': 243,
#  'drug': 329,
#  'escrow': 348,
#  'kill': 512,
#  'hold': 458,
#  'unless': 929,
#  'cars': 198,
#  'reasonable': 746,
#  'assume': 137,
#  'past': 665,
#  'high': 453,
#  'market': 579,
#  'clinton': 230,
#  'protect': 724,
#  'able': 81,
#  'security': 804,
#  'nsa': 635,
#  'court': 268,
#  'taking': 877,
#  'self': 806,
#  'defense': 292,
#  'turn': 919,
#  'law': 527,
#  'enforcement': 342,
#  'safety': 783,
#  'gun': 432,
#  'deleted': 294,
#  'doubt': 323,
#  'problem': 716,
#  'drivers': 327,
#  'held': 449,
#  'happened': 438,
#  'tried': 910,
#  'keyboard': 510,
#  'cable': 187,
#  'meaning': 587,
#  'weeks': 965,
#  'calls': 190,
#  'experience': 360,
#  'church': 221,
#  'sin': 824,
#  'didn': 304,
#  'true': 912,
#  'death': 290,
#  'act': 86,
#  'truth': 913,
#  'ground': 428,
#  'situation': 828,
#  'business': 183,
#  'men': 593,
#  'view': 948,
#  'women': 977,
#  'members': 591,
#  'killed': 513,
#  'figure': 379,
#  'necessary': 619,
#  'blood': 168,
#  'result': 770,
#  'advance': 93,
#  'moral': 609,
#  'claim': 225,
#  'consider': 253,
#  'allow': 101,
#  'pretty': 708,
#  'black': 166,
#  'goes': 419,
#  'hope': 460,
#  'correct': 262,
#  'strong': 862,
#  'sell': 807,
#  'serial': 811,
#  'dc': 287,
#  'printer': 711,
#  'couldn': 264,
#  'drives': 328,
#  'finally': 383,
#  'decided': 291,
#  'buy': 184,
#  'wanted': 955,
#  'pin': 680,
#  'gave': 405,
#  'scsi': 798,
#  'school': 793,
#  'press': 707,
#  've': 944,
#  'instead': 485,
#  'limited': 542,
#  'previous': 709,
#  'certain': 204,
#  'couple': 266,
#  'avoid': 145,
#  'anybody': 111,
#  'monitor': 606,
#  'size': 829,
#  'btw': 178,
#  'ram': 738,
#  'speed': 848,
#  'faster': 372,
#  'isn': 495,
#  'designed': 298,
#  'tax': 882,
#  'products': 720,
#  'cut': 277,
#  'development': 300,
#  'obvious': 639,
#  'single': 825,
#  'supply': 868,
#  'aren': 125,
#  'knew': 515,
#  'goal': 417,
#  'earth': 331,
#  'giving': 413,
#  'win': 971,
#  'took': 905,
#  'level': 536,
#  'perfect': 671,
#  'happen': 437,
#  'night': 630,
#  'hardware': 442,
#  'games': 403,
#  'mass': 580,
#  'hockey': 457,
#  'radio': 737,
#  'greek': 427,
#  'job': 504,
#  'getting': 409,
#  'happy': 440,
#  'die': 305,
#  'happens': 439,
#  'religious': 757,
#  'mind': 600,
#  'completely': 248,
#  'argument': 126,
#  'supposed': 871,
#  'folks': 387,
#  'bike': 163,
#  'insurance': 486,
#  'states': 855,
#  'break': 175,
#  'learn': 530,
#  'friend': 396,
#  'family': 368,
#  'told': 904,
#  'mentioned': 595,
#  'gets': 408,
#  'water': 960,
#  'local': 551,
#  'looked': 555,
#  'reported': 761,
#  'went': 966,
#  'coming': 238,
#  'weapons': 963,
#  'event': 350,
#  'hear': 447,
#  'christian': 218,
#  'existence': 357,
#  'hit': 456,
#  'police': 692,
#  'value': 940,
#  'board': 169,
#  'cause': 201,
#  'unit': 925,
#  'input': 482,
#  'late': 524,
#  'claims': 226,
#  'difficult': 308,
#  'war': 957,
#  'mode': 602,
#  'driver': 326,
#  'taken': 875,
#  'american': 105,
#  'talk': 878,
#  'started': 852,
#  '1990': 21,
#  'white': 967,
#  'engine': 343,
#  'trade': 908,
#  'opinion': 649,
#  'federal': 376,
#  'events': 351,
#  'values': 941,
#  'controller': 260,
#  'ide': 467,
#  'orbit': 651,
#  'opinions': 650,
#  'wait': 953,
#  'appreciate': 117,
#  'involved': 494,
#  'face': 364,
#  'gives': 412,
#  'action': 87,
#  'error': 347,
#  'db': 286,
#  'evidence': 352,
#  'clear': 228,
#  'position': 697,
#  'chance': 206,
#  'cases': 200,
#  'jobs': 505,
#  'floppy': 386,
#  'talking': 879,
#  'provide': 725,
#  'military': 598,
#  'ones': 647,
#  'results': 771,
#  'explain': 361,
#  'million': 599,
#  'shall': 816,
#  'takes': 876,
#  'functions': 399,
#  'int': 487,
#  'require': 764,
#  'wrote': 992,
#  'armenians': 129,
#  'armenia': 127,
#  'turkish': 917,
#  'turkey': 916,
#  'armenian': 128,
#  'ideas': 469,
#  'installed': 484,
#  'health': 446,
#  'physical': 677,
#  'teams': 884,
#  'players': 688,
#  'ed': 335,
#  'haven': 443,
#  'age': 94,
#  'hot': 461,
#  'individual': 479,
#  'society': 832,
#  'fbi': 375,
#  'dod': 317,
#  'guns': 433,
#  'bus': 182,
#  'saw': 789,
#  'thank': 892,
#  'brought': 177,
#  'jewish': 501,
#  'published': 731,
#  'launch': 526,
#  '01': 2,
#  'page': 660,
#  'study': 863,
#  '02': 3,
#  'division': 316,
#  'approach': 119,
#  'history': 455,
#  'congress': 252,
#  'rest': 769,
#  'authority': 142,
#  'gas': 404,
#  'soviet': 844,
#  'section': 802,
#  '1st': 26,
#  'russian': 782,
#  'population': 695,
#  'la': 520,
#  'pp': 704,
#  'laws': 528,
#  'false': 367,
#  '37': 51,
#  '39': 53,
#  'pl': 682,
#  'reference': 753,
#  'apr': 121,
#  'mb': 585,
#  'lost': 559,
#  'living': 548,
#  'wire': 974,
#  'wide': 968,
#  '145': 15,
#  'max': 583,
#  'xt': 994,
#  'ah': 97,
#  '34': 47,
#  'firearms': 385,
#  'turks': 918,
#  'wm': 976,
#  'pts': 728,
#  'sl': 830,
#  '9v': 79,
#  'w7': 952,
#  '0t': 7,
#  'bh': 159,
#  '1t': 27,
#  'gk': 415,
#  'cx': 278,
#  '0d': 6,
#  '3t': 55,
#  'd9': 279,
#  'ax': 147,
#  'lk': 549,
#  '7u': 71,
#  'g9v': 401,
#  'chz': 222,
#  '1d9': 25,
#  'bhj': 160,
#  'a86': 80,
#  '6ei': 66,
#  '34u': 48,
#  'stephanopoulos': 857,
#  '2tm': 41,
#  '7ey': 70,
#  'b8f': 148,
#  'giz': 414,
#  'bxn': 185,
#  '75u': 69,
#  '2di': 40}

# %%
type(tfidf)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
vocab.keys
# Out:
# <function dict.keys>

# %%
vocab.keys()
# Out:
# dict_keys(['sure', 'story', 'did', 'statement', 'media', 'pro', 'israeli', 'world', 'having', 'letter', 'try', 'think', 'reason', 'report', 'clearly', 'reports', 'received', 'government', 'makes', 'away', 'look', 'jews', 'got', 'power', 'expect', 'people', 'read', 'faq', 'actually', 'accept', 'hard', 'atheism', 'need', 'little', 'faith', 'runs', 'jim', 'sorry', 'oh', 'just', 'end', 'maybe', 'start', 'new', 'newsgroup', 'alt', 'won', 'big', 'don', 'points', 'like', 'know', 'ask', 'question', 'sort', 'want', 'continue', 'israel', 'stop', 'asking', 'questions', 'work', 'bad', 'attack', 'group', 'center', 'policy', 'research', 'change', 'product', 'area', 'clipper', 'came', 'key', 'yes', 'technology', 'drive', 'cost', 'use', 'present', 'man', 'street', 'going', 'especially', 'guy', 'probably', 'doesn', 'real', 'gov', 'year', 'air', 'voice', 'privacy', 'phone', 'line', 'close', 'pc', 'unfortunately', 'time', 'right', 'certainly', 'post', 'rules', 'does', 'matter', 'll', 'good', 'let', 'mail', 'edu', 'league', 'old', 'wasn', 'dead', 'jesus', 'appears', 'day', 'normal', 'ok', 'record', 'small', 'programs', '64', 'lot', '40', 'average', '20', '25', 'difference', 'great', 'simple', 'card', 'better', 'says', 'cards', 'offer', 'bought', 'problems', 'complete', 'check', 'called', 'performance', 'numbers', 'file', 'mr', '33', 'sounds', 'mean', 'peace', 'process', 'say', 'test', '18', 'months', 'known', 'terms', 'saying', 'reasons', 'make', 'california', 'allowed', 'force', 'food', 'leave', 'include', 'way', 'wouldn', 'light', 'electronic', 'remember', 'total', 'kind', 'memory', 'non', 'outside', '10', 'years', 'life', 'doing', 'legal', 'used', 'car', '100', '200', 'looks', 'easy', 'price', 'tell', 'thanks', 'archive', 'graphics', 'list', '1993', '04', '17', 'computer', 'posting', 'april', 'including', 'available', 'site', 'manager', 'mit', '27', 'directory', 'pub', 'usenet', 'news', 'answers', 'article', 'server', 'machine', 'send', 'message', 'help', 'body', 'places', 'information', 'changed', 'order', 'plan', 'soon', 'keys', 'subject', '3d', 'public', 'free', 'systems', 'stuff', 'thinking', 'making', 'lines', 'changes', 'text', '1992', 'copy', 'provided', 'contact', 'software', 'suggest', 'reading', 'comp', 'image', 'analysis', 'date', 'asked', 'john', 'nasa', 'official', 'included', 'comments', 'ftp', 'related', 'commercial', 'display', '11', 'data', 'files', '12', '13', '14', '15', 'space', 'shuttle', '16', 'scientific', '19', 'future', 'info', 'groups', 'usually', 'articles', 'posted', 'times', 'month', 'field', 'port', 'type', 'place', 'com', 'general', 'switch', 'network', 'word', 'following', 'user', 'anonymous', 'internet', 'address', 'cd', 'required', 'service', 'appreciated', 'au', '128', 'cs', 'ac', '24', 'uk', 'net', 'usa', 'x11', 'tape', 'sources', 'sites', 'note', 'users', 'united', 'number', 'things', 'response', 'email', 'unix', 'hours', 'days', 'later', '26', '03', '93', 'mac', 'son', 'written', 'dave', 'ca', 'range', 'package', 'ii', 'ms', 'dos', 'version', 'exists', 'author', 'source', '50', 'steve', 'interesting', 'hp', 'series', 'needs', 'sun', 'volume', 'excellent', 'based', 'machines', 'includes', 'house', 'solution', 'run', 'box', 'requires', 'uses', 'algorithm', 'command', 'interface', 'program', 'set', 'write', 'code', 'format', 'widget', 'applications', 'environment', 'device', 'library', 'fast', 'dr', 'output', 'support', 'major', '250', 'save', 'extra', 'al', 'looking', 'imagine', 'nice', 'object', 'material', 'cross', 'paper', 'project', 'various', 'technical', 'form', '000', 'community', 'org', 'access', 'wish', 'tools', 'writing', 'images', 'screen', 'windows', 'bit', 'gif', 'color', 'san', 'useful', 'books', 'tar', '75', 'means', 'north', 'america', '21', 'lots', 'book', 'trouble', 'specific', '36', '23', 'david', '31', 'multiple', 'created', '80', '32', 'mark', '35', '90', 'window', '38', 'manual', 'contains', '42', 'apparently', 'longer', 'language', 'standard', 'best', 'issues', 'jpeg', 'export', '30',  ...

# %%
np.count(vocab.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-aac869fb1980> in <module>
# ----> 1 np.count(vocab.keys())
#
# NameError: name 'np' is not defined

# %%
j
# Out:
# 2000

# %%
for i in vocab.keys():
    j+=1

# %%
tfidf[1][10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-30ca04327b99> in <module>
# ----> 1 tfidf[1][10]
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\scipy\sparse\_index.py in __getitem__(self, key)
#      33     """
#      34     def __getitem__(self, key):
# ---> 35         row, col = self._validate_indices(key)
#      36         # Dispatch to specialized methods.
#      37         if isinstance(row, INT_TYPES):
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\scipy\sparse\_index.py in _validate_indices(self, key)
#     133             row = int(row)
#     134             if row < -M or row >= M:
# --> 135                 raise IndexError('row index (%d) out of range' % row)
#     136             if row < 0:
#     137                 row += M
#
# IndexError: row index (10) out of range

# %%
vocab.values()
# Out:
# dict_values([872, 860, 303, 854, 589, 714, 497, 985, 444, 535, 914, 897, 745, 760, 229, 762, 748, 424, 573, 146, 554, 502, 422, 703, 359, 670, 741, 369, 88, 83, 441, 138, 620, 546, 366, 781, 503, 837, 644, 508, 341, 584, 851, 625, 627, 103, 978, 162, 321, 691, 540, 516, 134, 734, 838, 954, 258, 496, 859, 136, 735, 981, 149, 139, 429, 203, 693, 767, 207, 719, 124, 231, 191, 509, 997, 886, 325, 263, 931, 705, 575, 861, 420, 349, 434, 715, 319, 743, 423, 995, 98, 949, 712, 676, 543, 232, 668, 924, 900, 773, 205, 700, 778, 318, 582, 550, 421, 534, 569, 336, 529, 646, 959, 288, 500, 113, 284, 632, 645, 751, 831, 722, 65, 560, 56, 144, 28, 34, 306, 426, 822, 194, 158, 792, 195, 641, 173, 717, 247, 210, 189, 672, 637, 380, 612, 46, 840, 586, 669, 718, 790, 890, 19, 608, 518, 889, 791, 747, 572, 188, 102, 391, 390, 531, 475, 961, 987, 539, 338, 758, 907, 514, 592, 631, 658, 8, 996, 538, 320, 533, 932, 193, 9, 29, 557, 334, 710, 887, 893, 123, 425, 545, 24, 5, 18, 249, 702, 122, 478, 143, 826, 576, 601, 37, 311, 729, 934, 626, 109, 132, 813, 567, 808, 596, 451, 170, 684, 481, 208, 652, 685, 836, 511, 865, 54, 730, 394, 874, 864, 898, 574, 544, 209, 891, 23, 261, 726, 255, 833, 866, 742, 245, 471, 106, 281, 135, 506, 615, 643, 476, 240, 397, 754, 241, 314, 10, 280, 381, 11, 13, 14, 16, 845, 820, 17, 796, 20, 400, 480, 430, 939, 133, 701, 901, 607, 378, 696, 921, 683, 235, 406, 873, 624, 979, 389, 935, 107, 493, 91, 202, 765, 814, 118, 140, 12, 274, 82, 33, 922, 623, 930, 993, 880, 842, 827, 634, 936, 926, 636, 896, 768, 339, 928, 462, 285, 525, 36, 4, 78, 566, 835, 990, 282, 186, 739, 659, 470, 613, 322, 945, 358, 141, 841, 61, 858, 489, 464, 812, 622, 867, 950, 355, 151, 568, 477, 463, 834, 779, 174, 766, 937, 100, 239, 490, 721, 815, 988, 233, 393, 969, 116, 346, 301, 537, 371, 324, 657, 869, 571, 35, 788, 363, 99, 556, 473, 629, 638, 581, 273, 661, 723, 943, 885, 392, 1, 244, 653, 84, 975, 906, 989, 472, 797, 973, 164, 410, 234, 786, 933, 172, 881, 68, 588, 633, 104, 30, 561, 171, 911, 847, 50, 32, 283, 44, 614, 271, 72, 45, 578, 49, 75, 972, 52, 577, 256, 57, 112, 553, 522, 850, 157, 499, 507, 362, 42, 666, 750, 31, 114, 58, 251, 947, 76, 77, 492, 618, 958, 181, 795, 382, 356, 853, 267, 74, 254, 818, 309, 465, 445, 727, 315, 307, 776, 604, 165, 570, 398, 43, 521, 662, 299, 794, 344, 197, 89, 946, 236, 938, 590, 95, 64, 333, 67, 689, 777, 991, 772, 388, 759, 108, 655, 810, 763, 466, 964, 354, 690, 150, 345, 211, 192, 656, 276, 552, 998, 780, 839, 846, 411, 849, 870, 297, 488, 90, 152, 740, 310, 374, 787, 642, 775, 942, 270, 38, 22, 605, 755, 332, 377, 698, 60, 0, 313, 131, 167, 435, 679, 927, 73, 706, 843, 224, 295, 986, 39, 675, 856, 603, 302, 664, 269, 92, 817, 62, 153, 179, 115, 894, 563, 491, 448, 246, 674, 903, 673, 180, 999, 454, 384, 565, 681, 611, 610, 648, 909, 293, 275, 983, 597, 59, 785, 250, 744, 63, 749, 667, 888, 452, 85, 617, 532, 259, 418, 640, 547, 216, 902, 694, 120, 353, 214, 801, 212, 223, 130, 732, 713, 733, 799, 678, 899, 199, 407, 155, 474, 498, 784, 654, 161, 110, 156, 365, 217, 213, 809, 984, 752, 96, 823, 621, 915, 980, 523, 242, 805, 289, 920, 663, 819, 687, 982, 564, 483, 895, 541, 436, 370, 227, 468, 774, 736, 558, 395, 756, 883, 628, 330, 416, 616, 686, 800, 431, 265, 594, 373, 562, 923, 257, 220, 450, 154, 803, 196, 956, 219, 459, 176, 970, 215, 821, 337, 296, 340, 519, 699, 312, 517, 402, 951, 962, 237, 272, 243, 329, 348, 512, 458, 929, 198, 746, 137, 665, 453, 579, 230, 724, 81, 804, 635, 268, 877, 806, 292, 919, 527, 342, 783, 432, 294, 323, 716, 327, 449, 438, 910, 510, 187, 587, 965, 190, 360, 221, 824, 304, 912, 290, 86, 913, 428, 828, 183, 593, 948, 977, 591, 513, 379, 619, 168, 770, 93, 609, 225, 253, 101, 708, 166, 419, 460, 262, 862, 807, 811, 287, 711, 264, 328, 383, 291, 184, 955, 680, 405, 798, 793, 707, 944, 485, 542, 709, 204, 266, 145, 111, 606, 829, 178, 738, 848, 372, 495, 298, 882, 720, 277, 300, 639, 825, 868, 125, 515, 417, 331, 413, 971, 905, 536, 671, 437, 630, 442, 403, 580, 457 ...

# %%
print(tfidf)
# Out:
#   (0, 703)	0.12649800094895408
#   (0, 422)	0.11440503782900698
#   (0, 502)	0.16143119574434353
#   (0, 554)	0.11764823931486343
#   (0, 146)	0.1321150797895706
#   (0, 573)	0.13397806229297743
#   (0, 424)	0.1286860210682992
#   (0, 748)	0.16159319274170325
#   (0, 762)	0.16593512050235812
#   (0, 229)	0.16031961808699013
#   (0, 760)	0.16377738132726433
#   (0, 745)	0.13017163327559614
#   (0, 897)	0.08921604715652667
#   (0, 914)	0.1211198624990018
#   (0, 535)	0.170527849290146
#   (0, 444)	0.12553649604441633
#   (0, 985)	0.1234486147818597
#   (0, 497)	0.3492941756834514
#   (0, 714)	0.16687897474873634
#   (0, 589)	0.6706185322723434
#   (0, 854)	0.1548789339575849
#   (0, 303)	0.10688890801049414
#   (0, 860)	0.15939664046839722
#   (0, 872)	0.11320169009663988
#   (1, 321)	0.08508020140594663
#   :	:
#   (11313, 758)	0.12570119483680048
#   (11313, 747)	0.14997932614513387
#   (11313, 840)	0.14657229469463148
#   (11313, 637)	0.141706720017083
#   (11313, 210)	0.1348772638908091
#   (11313, 560)	0.11495605591940465
#   (11313, 646)	0.23429213451479058
#   (11313, 529)	0.1530140090979493
#   (11313, 421)	0.2673419220446111
#   (11313, 550)	0.2134325366551825
#   (11313, 773)	0.09899077953707168
#   (11313, 995)	0.11014958046561096
#   (11313, 434)	0.1482956437887185
#   (11313, 931)	0.08781268917834618
#   (11313, 191)	0.13080357079457747
#   (11313, 207)	0.128885319288103
#   (11313, 954)	0.0970980597351935
#   (11313, 516)	0.07806545706709957
#   (11313, 540)	0.07474539865541215
#   (11313, 321)	0.07749243178264985
#   (11313, 508)	0.1516724066748592
#   (11313, 88)	0.1142455422904154
#   (11313, 359)	0.14386393599752118
#   (11313, 422)	0.10733734840117418
#   (11313, 303)	0.10028554840820557

# %%
str(n_topics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-7d9180bcc758> in <module>
# ----> 1 str(n_topics)
#
# NameError: name 'n_topics' is not defined

# %%
str(300)
# Out:
# '300'

# %%
len(tfidf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-014c5a895354> in <module>
# ----> 1 len(tfidf)
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\scipy\sparse\base.py in __len__(self)
#     293     # non-zeros is more important.  For now, raise an exception!
#     294     def __len__(self):
# --> 295         raise TypeError("sparse matrix length is ambiguous; use getnnz()"
#     296                         " or shape[0]")
#     297
#
# TypeError: sparse matrix length is ambiguous; use getnnz() or shape[0]

# %%
k
# Out:
# 0

# %%
for i in range(len(tfidf)):
    k+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-5ed8cf430c3e> in <module>
# ----> 1 for i in range(len(tfidf)):
#       2     k+=1
#
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\scipy\sparse\base.py in __len__(self)
#     293     # non-zeros is more important.  For now, raise an exception!
#     294     def __len__(self):
# --> 295         raise TypeError("sparse matrix length is ambiguous; use getnnz()"
#     296                         " or shape[0]")
#     297
#
# TypeError: sparse matrix length is ambiguous; use getnnz() or shape[0]

# %%
a=([1,2,3,5,6,8],[6,8,9,6,5,3])

# %%
a
# Out:
# ([1, 2.3, 5, 6, 8], [6, 8, 9, 6, 5, 3])

# %%
tomatrix(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-4ed43bd920f3> in <module>
# ----> 1 tomatrix(a)
#
# NameError: name 'tomatrix' is not defined

# %%
b=np.mat(a)

# %%
import numpy as np

# %%
b
# Out:
# matrix([[1, 2, 3, 5, 6, 8],
#         [6, 8, 9, 6, 5, 3]])

# %%
print(b)
# Out:
# [[1 2 3 5 6 8]
#  [6 8 9 6 5 3]]

# %%
len(b)
# Out:
# 2
